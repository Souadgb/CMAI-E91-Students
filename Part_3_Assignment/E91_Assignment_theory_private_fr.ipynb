# %% [markdown]
# # Questions de compréhension
#
# Répondez aux questions suivantes.

# %% [markdown]
# ### Question 1
#
# Si Eve intercepte et mesure **100 %** des paires de Bell, quelle valeur CHSH attendriez-vous ?
#
# A) $|S|\approx 2\sqrt{2}$
#
# B) $|S|\le 2$
#
# C) $|S|\approx 2.5$

# %% [markdown]
# ### Question 2
#
# Alice et Bob exécutent le protocole E91 et mesurent **S = 2,1**.
# Doivent-ils utiliser la clé ?
#
# A) Oui — tout $S > 2$ est considéré comme sécurisé
# B) Non — c'est trop proche de la limite classique
# C) Oui — mais seulement s'ils rejettent la moitié de la clé

# %% [markdown]
# ### Question 3
#
# Pourquoi le protocole E91 utilise-t-il une combinaison de bases de mesure **identiques** et **différentes** ?
#
# A) Bases identiques pour la génération de clé ; bases différentes pour permettre le test de Bell CHSH
# B) Les mêmes bases sont requises pour les deux tâches
# C) Les bases différentes n’augmentent que la longueur de la clé

# %% [markdown]
# ### Question 4
#
# Comment le protocole E91 détecte-t-il l'espionnage ?
#
# A) En comparant publiquement un sous-ensemble des bits de la clé
# B) En vérifiant si le test CHSH viole l'inégalité de Bell ($|S| > 2$)
# C) En vérifiant que le message chiffré reste lisible
